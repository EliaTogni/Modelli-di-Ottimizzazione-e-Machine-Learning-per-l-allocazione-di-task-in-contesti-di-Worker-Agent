# %%
import pandas as pd

def main():
    df = pd.read_csv("../../Dataset/Game Sessions.csv")
    print(df)


if __name__ == "__main__":
    main()
# Out:
#                                                      ID  \
# 0                  8f69d8e2-6b49-4e8d-b507-fd507305f712
# 1                  e21c4992-c14f-4344-96bf-81c883e46dc2
# 2                  58e16a92-dc70-414b-a7d2-51fb17fb0093
# 3                  76207e9e-bf8b-46b2-9652-2e177fedb72f
# 4                  09637dcd-4b96-4b97-ad21-fc56fd966523
# ...                                                 ...
# 9849  b5f45ab2-2531-4e98-87f9-f121a42aa1ea[sduzss][2...
# 9850  e3da13e8-c709-436d-8ae2-11f336549220[961231][2...
# 9851  c1888e82-4f53-4737-a934-ab8420c4c7e8[zyc][2016...
# 9852  009cf97f-371d-4522-8b7c-8bdba1be13cf[sdull][20...
# 9853  cd84120a-a56f-4191-adcf-a807eb50f017[sdu_wangy...
#
#                                                 User ID  Game Level  \
# 0                  00212664-6c71-4e24-b61d-c7776f7a7d99           1
# 1                  00212664-6c71-4e24-b61d-c7776f7a7d99           1
# 2                  35112a97-3b76-43e4-a403-6ce0bf79fb6b           1
# ...
