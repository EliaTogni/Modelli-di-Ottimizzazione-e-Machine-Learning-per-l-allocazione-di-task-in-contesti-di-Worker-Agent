# %%
import pandas as pd

tasks = pd.read_csv("../Dataset 2.0/Tasks.csv")
tasks = tasks.drop(0, axis = 0)
tasks = tasks.drop("Deadline", axis = 1)
tasks
# Out:
#     ID  Value  Difficulty  Effort Required  Deadline
# 1    1      4         0.8                4         1
# 2    2      2         0.4                2         1
# 3    3      5         1.0                5         1
# 4    4      4         0.8                4         1
# 5    5      3         0.6                3         1
# 6    6      3         0.6                3         1
# 7    7      4         0.8                4         1
# 8    8      3         0.6                3         1
# 9    9      3         0.6                3         1
# 10  10      4         0.8                4         1
# 11  11      2         0.4                2         1
# 12  12      1         1.0                1         1
# 13  13      1         1.0                1         1
# 14  14      4         0.8                4         1
# 15  15      3         0.6                3         1
# 16  16      3         0.6                3         1
# 17  17      3         0.6                3         1
# ...

# %%
from mip import *
