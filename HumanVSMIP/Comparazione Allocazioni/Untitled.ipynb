# %% [markdown]
# Le sessioni di gioco prese in considerazione sono scelte tra le game session con score più alto tra quelle che self reportano la strategia analizzata.\newline
# Per ciascuna analisi, si è scelto di confrontare l'allocazione delle task del giocatore, l'allocazione ritenuta ideale per quella strategia e l'allocazione effettuata dal modello.\newline
# La bontà di ogni allocazione è valutata tramite score percentuale, calcolato come value delle task portate a termine con successo diviso value totale delle task.
#
#
# ### Load Balance Based Allocation ###
#
# _bfce2734-f71a-4ce9-8754-663ce6b25b64_ e _d388aeed-67b9-45a3-bcb1-b403e9dd7820_
#
#
# #### Primo caso ####
#
# La strategia applicata, in questo caso, corrisponde a distribuire equamente le task tra i WA. Quindi, ognuno dei 10 WA avrà 3 task da svolgere (il WA 1 proverà a svolgere le task "1, 2 e 3", il WA 2 proverà a svolgere le task "4, 5 e 6", ecc.).\newline
# Lo score ottenuto in questa maniera è di 40/89.\newline
# Il modello, invece, assegna le task \newline
# Lo score è di .\newline
# Proviamo ora a calcolare lo score con i coefficienti al round 9. \newline
# Il modello assegna le task . \newline
# In questo caso, lo score è di .
#
#
# #### Secondo caso analizzato ####
#
# La strategia, anche in questo caso, corrisponde a distribuire equamente le task tra i WA.\newline
# Lo score rimane di 40/89.\newline
# Il modello invece assegna le task .\newline
# Lo score in questo caso è di .\newline
# Provo a calcolare lo score con i coefficienti al round 9 ed ottengo. Quindi, uno score di .
#
#
# ### Random Based Allocation###
#
# _a5690cea-12d8-43e2-9051-8384707f5419_ e _0bdcbc28-40cc-4b45-9c11-d34fd5df4a94_
#
#
# #### Primo caso analizzato ####
#
# la strategia, in questo caso, corrisponde ad una allocazione totalmente randomica delle task all'interno dell'Agile Manager Simulator. Per simulare questa allocazione uso un generatore di numeri random in un range 1 - 10 per ogni task ( associo la task ad un WA definito ).
# Assegno la task \quotes{16} al WA 1, le task \quotes{8, 12, 30} al WA 2, le task \quotes{2, 7, 13, 15, 27} al WA 3, le task \quotes{14, 17} al WA 4, le task \quotes{18, 23} al WA 5, le task \quotes{24, 28} al WA 6, le task \quotes{1, 3, 5, 19, 21, 25} al WA 7, le task \quotes{9, 22, 26} al WA 8, le task \quotes{4, 6, 11, 20} al WA 9 e la task \quotes{29} al WA 10.
# \newline
# Lo score ottenuto è di 30/89.
# \newline
# Confronto questo score con quello del modello al round 2. Il modello assegna le task \quotes{6, 14} al WA 1, le task \quotes{4, 11, 13, 23} al WA 2, le task \quotes{8, 9, 17, 18, 21, 24} al WA 3, le task \quotes{10, 20, 22, 27} al WA 4, le task \quotes{1, 5, 12, 28} al WA 6, la task \quotes{30} al WA 7, la task \quotes{25} al WA 9 e le task \quotes{2, 3, 7, 15, 16, 19, 26, 29} al WA 10.
# \newline
# Lo score ottenuto è quindi di 31/89.
# \newline
# Al round 9, il modello si comporta come nel caso Load Balance; otteniamo, quindi, uno score di 44/89.
# Presupponendo la stessa allocazione di task in maniera randomica, possiamo confrontarlo con uno score di 30/89.
#
#
# #### Secondo caso analizzato ####
#
# Il modello assegna le task \quotes{1, 2, 3, 4, 7, 11, 13, 18, 20, 24, 26, 27, 30} al WA 13, le task \quotes{5, 10 , 17, 21} al WA 15,  le task \quotes{8, 12, 14, 15, 16, 19, 23, 25, 28} al WA 16 e le task \quotes{6, 9, 22, 29} al WA 17.
# \newline
# Lo score calcolato con questa allocazione è pari a 19/89.
# \newline
# Lo score ottenuto invece con l'allocazione random applicata nello stesso modo della sessione precedente risulta pari a 30/89.
# Per quanto riguarda il round 9, l'assegnazione delle task ai WA si rivela ancora uguale.
# \newline
# Avremo quindi uno score di 44/89, contro i 30/89 dell'assegnazione randomica.
#
#
# ### Reputation Based Allocation ###
#
# _029f1214-7513-407e-b219-379c3587483f_ e _572487c5-e5f7-49e7-bb09-193a49e743ab_
#
#
# #### Primo caso analizzato ####
#
# La strategia, in questo caso, si basa sulla reputazione del WA a inizio round; più è alta questa reputation, più saranno difficili e numerose le task a lui assegnate. Per quanto riguarda il round 2, assegno le task con \quotes{Effort Required} più alto ai WA con la reputation più alta; in caso di ex-aequo, scelgo casualmente. Seguendo questa strategia, ho assegnato le task \quotes{2, 5, 11, 13, 20} al WA 1, le task \quotes{5, 12, 22} al WA 2, le task \quotes{8, 18, 24} al WA 3, le task \quotes{6, 15, 16} al WA 4, le task \quotes{3, 27} al WA 5, le task \quotes{1, 14, 28} al WA 6, le task \quotes{4, 17, 21} al WA 7, le task \quotes{7,23, 26} al WA 8, le task \quotes{9, 19, 29} al WA 9 e le task \quotes{10, 25, 30} al WA 10.\newline
# Lo score ottenuto sarà di 35/89.\newline
# Il modello invece assegna le task .\newline
# \newline
# Calcoliamo ora gli score per il round 9: Il modello .\newline
# Invece, assegnando le task seguendo la strategia basata sulle reputazioni, ho assegnato le task \quotes{22, 26} al WA 2, le task \quotes{13, 20} al WA 3, le task \quotes{11, 12, 30} al WA 4, le task \quotes{2, 19, 21} al WA 5, le task \quotes{5, 6, 8, 17} al WA 6, le task \quotes{9, 15, 16, 18} al WA 7, le task \quotes{1, 3, 4, 27} al WA 8, le task \quotes{23, 24, 25, 28} al WA 9 e le task \quotes{7, 10, 14, 29} al WA 10.
# \newline
# Lo score ottenuto è di ben 71/89, di gran lunga superiore a qualsiasi altra scelta di allocazione.
#
#
# #### Secondo caso analizzato ####
#
# Nel round 2, il modello alloca le task .\newline
# L'allocazione secondo Reputation assegna le task .\newline
# In questo modo otteniamo uno score di .
# \newline
# Al round 9 invece, il modello applica .\newline
# Assegnando le task in maniera reputation based, cioè le task \quotes{22, 26} al WA 12, le task \quotes{7, 10, 14, 23} al WA 13, le task \quotes{5, 6, 25, 28} al WA 14, le task \quotes{8, 9, 15, 16} al WA 15, le task \quotes{1, 3, 4, 27} al WA 16, le task \quotes{13, 30} al WA 17, le task \quotes{11, 12, 30} al WA 18, le task \quotes{2, 24,2 9} al WA 19 e le task \quotes{17, 18, 19, 21} al WA 20.
# \newline
# Si ottiene così uno score di 24/89.
#
#
# ### Uniform Task Allocation ###
#
# Sostanziamente, osservando le allocazioni fatte dai giocatori, questa strategia spesso e volentieri si sovrappone al classico _Load Balance_ quindi non effettuerò un'ulteriore analisi di score in quanto sarebbe ripetitiva.
