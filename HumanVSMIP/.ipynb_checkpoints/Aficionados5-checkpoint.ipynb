# %%
import pandas as pd
import numpy as np

#Importo il .csv contenente le varie sessioni di gioco
game_session = pd.read_csv("../Dataset 2.0/Game Sessions.csv")

#Estraggo da questo file 
uniquePlayers = np.unique(game_session["User ID"])

#Estraggo una lista di tutti i giocatori con un numero di partite giocate maggiroe di 30
users = []
for i in uniquePlayers:
    tmp = game_session[game_session["User ID"] == i]
    if len(tmp) > 30:
        users.append(i)
        
        
print(f"Sono presenti {len(users)} users con più di 30 game session giocate: {users}")
# Out:
# Sono presenti 34 users con più di 30 game session giocate: ['000a62d8-5e6d-4532-ad99-af8a92a7e7f3', '00212664-6c71-4e24-b61d-c7776f7a7d99', '12b5a3b6-ccd8-4259-9943-ea4d34a89a1a', '28c1a568-4a34-4c0a-90c9-da8150390e88', '2fe37a4e-2f03-4573-844f-ee523105dc00', '3452d36a-8ed4-4253-b9db-d8fbeb74638e', '453c69f9-3e08-46f4-9c34-b036575a342e', '46da2a87-6999-4690-a45f-89f69c9d9a15', '4a7b26aa-bed3-4660-8014-fa2d51e21030', '4a8258fd-a3fc-4816-afc7-9f62a17a0664', '574e89d2-8320-4f63-a8e4-4d25fb9b3e8d', '6afc891c-1442-4d1d-9660-00e28fa16489', '6e9c88f4-0b93-4c2f-a681-a72a30e41b64', '704e4795-fc54-4e87-a764-aa49ba52011d', '70506f5d-00ac-4ac5-9e9c-6fd6406016af', '74ddab53-3849-4848-a0df-efb50e0eba8f', '85c24634-825e-4f55-99e7-fe3c1c00ebbc', '863b4b11-6da2-44b9-8e21-4f5954ed5b04', '8db00f0c-87e8-4515-b73e-2e67244c7198', '92927f86-f921-4e6d-996e-9f337b6b2877', '9caf068d-5e86-4818-8d83-379ea55d4e6f', '9da6520c-97c9-4c23-9d6a-ea5a603b5163', 'adc3fcd1-e4bf-42a5-b9c6-5a9a0b307cef', 'bdf52837-f61c-402a-b1c5-5d5b943b51b1', 'c1f00487-661e-4dd1-9bdb-7f22e3fb0025', 'c5576f06-432f-4aaf-bc88-a18dfc2b213f', 'c785d937-d9a7-42a7-8596-4f41c550d747', 'cfab3001-b954-4a01-a1c6-b8173a2f0a36', 'e4a00228-4aad-4830-b9fb-6fc200792ec1', 'ea6e6aa6-c30a-4e8b-92ea-97fa67a27df2', 'f2dabbf8-5e14-4107-93b1-5384f1538a0d', 'f5901766-c557-4207-87cb-974e588b2351', 'f836c650-861b-4348-9c0a-554a13aaf310', 'f8692315-0df8-4d7c-b3f1-7b1970ab72b3']

# %%
#Estraggo ora solamente le sessioni di gioco riferite al livello 5
lista = []
for i in users:
    tmp = game_session[game_session["User ID"] == i]
    tmp = tmp[tmp["Game Level"] == 5]
    for i in range(len(tmp)):
        lista.append(tmp.iloc[i, 0])

#
lista = np.array(lista)
lista = np.unique(lista)

#elimino tutte le sessioni di gioco abbandonate prima della sua conclusione
lista = np.delete(lista, 10)
lista = np.delete(lista, 17)
lista = np.delete(lista, 46)
lista = np.delete(lista, 52)
lista = np.delete(lista, 52)
lista = np.delete(lista, 52)
lista = np.delete(lista, 52)
lista = np.delete(lista, 54)
lista = np.delete(lista, 57)
lista = np.delete(lista, 68)
lista = np.delete(lista, 72)
lista = np.delete(lista, 8)

lista
# Out:
# array(['02647ffb-6535-4f65-adc5-bc7e0e5bbc66',
#        '04405414-779d-437e-bc69-acf40f360ebc',
#        '051262ae-0fa8-4cca-bf15-de13f642a650',
#        '05e60fc4-b904-458d-afff-6159361712fd',
#        '068743d5-598c-41a3-9dcf-77e1814d6580',
#        '0bf5d0e8-02e8-49ee-9b89-bb0f8db54411',
#        '0e0f74c2-66f1-4907-b7fa-0d4966c56024',
#        '13d3f7d2-f76b-4139-bbb1-f1544bf24064',
#        '1b6a2d87-f9ed-4801-8e51-d9a81dcba0c5',
#        '2004a003-2220-4048-b729-9ad3992ae317',
#        '209226d8-33ee-48c5-a804-cfdb60a3637b',
#        '220dd9e7-9cbf-46a9-beb2-b9a8a7fb26a2',
#        '25a29012-5588-4ac7-8f0d-2c85eb0b82f5',
#        '2eb6e7d5-9b37-432a-9117-70208d26d367',
#        '322c0dcd-1d60-40ca-b3d4-ebb47d101368',
#        '33e64dfe-3cf8-4915-8072-d7b80dc686e6',
#        '392d84c3-2cf6-4585-8826-bb4947606f3a',
#        '3cf27348-3c3b-4756-b995-d4cb6f197a48',
#        '43b6718e-510e-4c29-9a5a-650070c8be5f',
#        '443087ea-d194-4a51-b260-cee6b83d4eca',
#        '4687399c-0010-433b-a437-63a061a4f034',
#        '4e92f0a6-6cbd-40e7-92c6-c90bd6c1e66d',
#        '516ea01a-bf11-4c4e-adc5-49c77821bd02',
#        '53513833-6918-4ab9-bd4f-f807b7ac8060',
#        '5872f349-1e97-4e48-a82c-13dbf3248765',
#        '58bf53a6-a9f5-41bd-b897-cb34bfc6de84',
#        '5af75049-6237-43ce-8d3f-33b9563b8e8d',
#        '60962238-2bc2-4f52-9eea-f745fd7c2126',
#        '696c0667-8668-447d-867f-ca5a478b42d9',
#        '6b89de4e-80eb-4fe8-90c2-3a5b9d75b01d',
#        '7051f5b7-ee8b-4ce3-b5b1-13ef28576581',
#        '77f7a3d2-6e30-4fb8-9179-74ae580ee99a',
#        '7ad6baba-4a99-473b-8942-e8915aabc780',
#        '7d2bec9f-c108-4df1-a4a3-63e7125ba649',
#        '869622a4-ed0a-472b-b8a9-c49324397088',
#        '899633cd-4fd3-463c-98b7-10b1423daf45',
#        '91c9f6dc-c341-4820-a0ca-9dd11c8e5924',
#        '95e325b7-0505-4c1a-9de4-5d7aac6007c1',
#        '983c1257-3b9d-42a3-a7b2-f61662666487',
#        '9cab399f-86e8-4397-ad34-6a4e942da39a',
#        '9f215c07-5037-46e0-9137-c0745ad08f72',
#        'a0e4c34e-fa9a-4c23-909e-756a650c349a',
#        'a49076b3-3e2b-4d60-8c3d-880a44db0e6a',
#        'ab047369-1b18-4ed9-9ef6-bfbc6b074281',
#        'ac4ee2b3-3f07-43cb-b904-ccbae4f423b6',
#        'aef97aca-4a32-416a-a067-40d4de28e898',
#        'af6bcaf6-31a0-4f72-af4d-bcdf26895f88',
#        'b1cc2d30-d642-46b6-b5e7-314a65965a27',
#        'b48654a8-d821-4508-8ce6-a52b31f6c71e',
#        'b6e18bbe-1c35-461d-98e8-5a52f3099574',
#        'b79e013c-74f6-4c1b-9f6a-3e9ca6948912',
#        'bfce2734-f71a-4ce9-8754-663ce6b25b64',
#        'c0d30e25-4a59-4e3c-b3d9-2c165744793f',
#        'c3302808-38fa-4f49-a4e0-b6b6bb2a9ea8',
#        'c673ca6d-116c-41e0-b87b-0b6be5edb373',
#        'c774e933-8fd9-48d2-ab6b-fdf939760e98',
#        'cc25aa67-67bf-42d3-a332-6d9d5bd0f520',
#        'ccfb8830-08fb-4462-9e7a-a16034f65024',
#        'd34c301f-2abc-4277-a1ef-ef38935f68b2',
#        'd491e62d-beab-4b98-9967-57db5d64ad1b',
#        'd4bb8c6c-18e6-46a7-9ee9-bc8c50119e55',
#        'd875c370-f30b-473b-9638-e3af466866c4',
#        'd9151f3b-1e2a-4885-b9ea-9d5cf2b745da',
#        'dc258a3e-b6c6-4be3-ab24-c37eb9242bcd',
#        'dcbb9bcd-53a2-4c12-ab7e-7f6e6125da64',
#        'dec8ca47-c9f9-4943-a477-b69d95a3a3f0',
#        'df1a5bdb-034c-414b-a469-46c8d85b4c24',
#        'e57a46a3-8e45-4fa8-a5b6-30ddf0def6ac',
#        'efbfa117-850d-4d95-b764-4fd553f3cdf2',
#        'f0dd6513-a5cd-432d-8792-eb32bb328d6d',
#        'f10f5f3e-cc5f-4230-8395-13977fe4f173',
#        'fb57064d-bc98-4221-b0fa-8fd036c9ba30'], dtype='<U36')

# %%
#Importo le informazioni riguardanti le qualità delle tasks 
tasks = pd.read_csv("../Dataset 2.0/Tasks.csv")
tasks = tasks.drop(0, axis = 0)
tasks = tasks.drop("Deadline", axis = 1)


#Importo i coefficienti di regressione di ogni agente
coeffs = pd.read_csv("../Coefficienti di Regressione/coeffs.csv")

#Estraggo solamente i risultati del round desiderato
decisions = pd.read_csv("../Dataset 2.0/Decisions.csv")
decisions = decisions[decisions["Round"] == 9]
decisions
# Out:
#              ID                            Session ID  Round  Worker Agent ID  \
# 630        1521  cd6b97eb-16f5-486e-a29b-c3baf4c2baec      9               11
# 631        1523  cd6b97eb-16f5-486e-a29b-c3baf4c2baec      9               16
# 632        1525  cd6b97eb-16f5-486e-a29b-c3baf4c2baec      9               20
# 633        1527  cd6b97eb-16f5-486e-a29b-c3baf4c2baec      9               13
# 634        1529  cd6b97eb-16f5-486e-a29b-c3baf4c2baec      9               14
# ...         ...                                   ...    ...              ...
# 495388  1290646  b206c2c6-de43-414a-abbf-af57e750f906      9               16
# 495389  1290648  b206c2c6-de43-414a-abbf-af57e750f906      9               17
# 495390  1290650  b206c2c6-de43-414a-abbf-af57e750f906      9               18
# 495391  1290652  b206c2c6-de43-414a-abbf-af57e750f906      9               19
# 495392  1290654  b206c2c6-de43-414a-abbf-af57e750f906      9               20
#
#         Worker Agent Reputation
# 630                    0.093912
# 631                    0.307397
# 632                    0.319685
# 633                    0.160180
# 634                    0.313495
# ...                         ...
# 495388                 0.548162
# 495389                 0.690501
# 495390                 0.577292
# 495391                 0.774562
# 495392                 0.633201
#
# [18277 rows x 5 columns]

# %%
from mip import *


for i in lista:
    stringa = ""
    stringa = stringa + i + ", "
    #Selezionare il Session ID ed il Round voluti
    #Assicurarsi di selezionare lo stesso round in "RegressionModel.py" e in "OptimizationModel.py"
    decisions1 = decisions[decisions["Session ID"] == i]
    decisions1 = decisions1.sort_values("Worker Agent ID")
    m = Model()
    m.verbose = 0

    #DATI


    #Identifier del Worker Agent
    WAID = list(decisions1["Worker Agent ID"])

    #Peso dell'Identifier del WA
    wWAID = coeffs.iloc[91].values.tolist()

    if (WAID[9] == 10):
        wWAID = wWAID[0:10]

    else:
        wWAID = wWAID[10:20]

    #Identifier del Round
    dID = list(decisions["ID"])


    #Peso dell'Identifier del round
    wdID = coeffs.iloc[0].values.tolist()

    if (WAID[9] == 10):
        wdID = wdID[0:10]

    else:
        wdID = wdID[10:20]


    #Value di ogni task
    Value = []
    for h in tasks["Value"]:
        Value.append(int(h))


    #Peso del Value (coeffs 1, 4, 7, ..., 88)
    wValue = []

    j = 1
    for k in range(30):
        wValue.append(coeffs.iloc[j].values.tolist())
        j = j + 3

    if (WAID[9] == 10):
        for h in range(30):
            wValue[h] = wValue[h][0:10]

    else:
        for h in range(30):
            wValue[h] = wValue[h][10:20]


    #Complessità di ogni task
    Difficulty = []
    for h in tasks["Difficulty"]:
        Difficulty.append(float(h))


    #Peso della Complessità (coeffs 2, 5, 8, ..., 89)
    wDifficulty = []

    j = 2
    for k in range(30):
        wDifficulty.append(coeffs.iloc[j].values.tolist())
        j = j + 3

    if (WAID[9] == 10):
        for h in range(30):
            wDifficulty[h] = wDifficulty[h][0:10]

    else:
        for h in range(30):
            wDifficulty[h] = wDifficulty[h][10:20]


    #Stamina consumata da ogni task
    Effort = []
    for h in tasks["Effort Required"]:
        Effort.append(int(h))


    #Peso della Stamina consumata (coeffs 3, 6, 9, ..., 90)
    wEffort = []

    j = 3
    for k in range(30):
        wEffort.append(coeffs.iloc[j].values.tolist())
        j = j + 3

    if (WAID[9] == 10):
        for h in range(30):
            wEffort[h] = wEffort[h][0:10]

    else:
        for h in range:
            wEffort[h] = wEffort[h][10:20]

    #Reputazione del WA prima del round
    Rep = list(decisions1["Worker Agent Reputation"])


    #Peso della reputation
    wRep = coeffs.iloc[92].values.tolist()

    if (WAID[9] == 10):
        wRep = wRep[0:10]

    else:
        wRep = wRep[10:20]

    #creo i range utili per la creazione di variabili
    (A, T) = (range(len(WAID)), range(len(Value)))

    #VARIABILI

    #x[a, t] vale 1 se la task t è assegnata al WA a, 0 altrimenti
    x = [[m.add_var(var_type=BINARY) for t in T] for a in A]

    #y(a) contiene la reputation del WA a fine round
    y = [m.add_var(var_type=CONTINUOUS) for a in A]


    #VINCOLI

    #Vincolo che impone che ogni task venga assegnata ad uno ed un solo WA
    for t in T:
        m += xsum(x[a][t] for a in A) == 1


    #OBIETTIVO
    #Massimizzare la sommatoria delle reputation dei worker agent
    m.objective = maximize(xsum(dID[a]*wdID[a] for a in A) + xsum(wValue[t][a]*Value[t]*x[a][t] + wDifficulty[t][a]*Difficulty[t]*x[a][t] + wEffort[t][a]*Effort[t]*x[a][t] for t in T for a in A) + xsum(wRep[a]*Rep[a] + wWAID[a]*WAID[a] for a in A))

    m.write("model.lp")
    m.optimize()

    stringa = stringa +str(m.objective_value) + ", "



    decisions2 = pd.read_csv("../Dataset 2.0/Decisions.csv")

    #Da "Decisions.csv" seleziono solo le tuple riguardanti il round successivo
    decisions2 = decisions2[decisions2["Round"] == 10]

    #Estraggo "Session ID", "Worker Agent ID" e "Worker Agent Reputation"
    decisions2 = decisions2.iloc[:, [1, 3, 4]]
    decisions2 = decisions2[decisions2["Session ID"] == i]
    tmp1 = pd.merge(decisions1, decisions2, left_on = "Worker Agent ID", right_on = "Worker Agent ID")

    tmp1 = tmp1.iloc[:, [0, 1, 2, 3, 4, 6]]

    #calcolo lo score corrispondente ottenuto dal player umano
    totale = 0
    for k in range(len(tmp1)):
        totale += tmp1.iloc[k, 5]
    stringa = stringa + str(totale)
    print(stringa)
# Out:
# 02647ffb-6535-4f65-adc5-bc7e0e5bbc66, 6.379133759868655, 6.315242348847139
# 04405414-779d-437e-bc69-acf40f360ebc, 5.454717641578917, 5.410147850830864
# 051262ae-0fa8-4cca-bf15-de13f642a650, 6.087788330107559, 6.152206339499513
# 05e60fc4-b904-458d-afff-6159361712fd, 6.128735827226628, 6.27357480220401
# 068743d5-598c-41a3-9dcf-77e1814d6580, 6.764333136651972, 6.827810616834687
# 0bf5d0e8-02e8-49ee-9b89-bb0f8db54411, 6.33740653652613, 6.416011638884545
# 0e0f74c2-66f1-4907-b7fa-0d4966c56024, 6.5431300181010466, 6.30527933358033
# 13d3f7d2-f76b-4139-bbb1-f1544bf24064, 4.906181348351954, 4.8796863898868565
# 1b6a2d87-f9ed-4801-8e51-d9a81dcba0c5, 6.260615958107575, 6.208942248875541
# 2004a003-2220-4048-b729-9ad3992ae317, 5.888839365416853, 5.9459390331675985
# 209226d8-33ee-48c5-a804-cfdb60a3637b, 6.192624094331154, 6.489262883911261
# 220dd9e7-9cbf-46a9-beb2-b9a8a7fb26a2, 5.72442717642047, 5.653928803832848
# 25a29012-5588-4ac7-8f0d-2c85eb0b82f5, 5.422899235351011, 5.451509322234976
# 2eb6e7d5-9b37-432a-9117-70208d26d367, 5.610495795184484, 5.706920136680386
# 322c0dcd-1d60-40ca-b3d4-ebb47d101368, 6.752617570381973, 6.722798698355868
# 33e64dfe-3cf8-4915-8072-d7b80dc686e6, 4.420025947507087, 4.465894153385396
# 392d84c3-2cf6-4585-8826-bb4947606f3a, 5.113560678808554, 5.096474325438319
# 3cf27348-3c3b-4756-b995-d4cb6f197a48, 5.8734598948073815, 5.999897910606972
# 43b6718e-510e-4c29-9a5a-650070c8be5f, 6.546851498052376, 6.6412193023221
# 443087ea-d194-4a51-b260-cee6b83d4eca, 5.176096512603448, 5.1385082913796465
# 4687399c-0010-433b-a437-63a061a4f034, 5.927340764298589, 5.660339569832504
# 4e92f0a6-6cbd-40e7-92c6-c90bd6c1e66d, 5.983952955203606, 6.305197407330962
# 516ea01a-bf11-4c4e-adc5-49c77821bd02, 6.0651236378589175, 5.887003696930437
# 53513833-6918-4ab9-bd4f-f807b7ac8060, 6.8695313185464615, 6.9462358549144065
# 5872f349-1e97-4e48-a82c-13dbf3248765, 6.66108496506268, 6.895394064958554
# 58bf53a6-a9f5-41bd-b897-cb34bfc6de84, 5.725167259704284, 5.98662994600104
# 5af75049-6237-43ce-8d3f-33b9563b8e8d, 6.579458339589015, 6.794602478957828
# 60962238-2bc2-4f52-9eea-f745fd7c2126, 5.295023940185569, 5.278282635616482
# 696c0667-8668-447d-867f-ca5a478b42d9, 5.313139011543367, 5.806581341135791
# 6b89de4e-80eb-4fe8-90c2-3a5b9d75b01d, 5.601604948740956, 5.628497839680057
# 7051f5b7-ee8b-4ce3-b5b1-13ef28576581, 6.710936579499147, 6.916042171725773
# 77f7a3d2-6e30-4fb8-9179-74ae580ee99a, 6.873267614788611, 7.060622659890637
# 7ad6baba-4a99-473b-8942-e8915aabc780, 5.190713743212896, 5.391715911998141
# 7d2bec9f-c108-4df1-a4a3-63e7125ba649, 6.157013823167077, 6.3371387591483375
# 869622a4-ed0a-472b-b8a9-c49324397088, 7.0325019308215735, 7.258951433901415
# 899633cd-4fd3-463c-98b7-10b1423daf45, 5.2246830603942644, 5.089429924953513
# 91c9f6dc-c341-4820-a0ca-9dd11c8e5924, 5.847812568790403, 5.994181129828221
# 95e325b7-0505-4c1a-9de4-5d7aac6007c1, 6.538191661886845, 6.650538176935323
# 983c1257-3b9d-42a3-a7b2-f61662666487, 7.058561396648965, 7.1462266307259945
# 9cab399f-86e8-4397-ad34-6a4e942da39a, 6.011378824672053, 6.056479942716084
# 9f215c07-5037-46e0-9137-c0745ad08f72, 5.846701892956673, 5.951106321606195
# a0e4c34e-fa9a-4c23-909e-756a650c349a, 5.178238122021579, 5.246435474117725
# a49076b3-3e2b-4d60-8c3d-880a44db0e6a, 6.843068028343886, 6.990733522241336
# ab047369-1b18-4ed9-9ef6-bfbc6b074281, 6.3930726456127465, 6.573485611186635
# ac4ee2b3-3f07-43cb-b904-ccbae4f423b6, 5.743829453967673, 5.5291789479946925
# aef97aca-4a32-416a-a067-40d4de28e898, 6.309235800036674, 6.502822150977221
# af6bcaf6-31a0-4f72-af4d-bcdf26895f88, 5.851869294765259, 5.690503240550428
# b1cc2d30-d642-46b6-b5e7-314a65965a27, 6.332196445085332, 6.399305555820099
# b48654a8-d821-4508-8ce6-a52b31f6c71e, 4.901622243673838, 4.958052064270506
# b6e18bbe-1c35-461d-98e8-5a52f3099574, 7.028079549411965, 7.1457140507368235
# b79e013c-74f6-4c1b-9f6a-3e9ca6948912, 6.032244399003786, 6.065924149599582
# bfce2734-f71a-4ce9-8754-663ce6b25b64, 7.009720823198988, 7.26872035194039
# c0d30e25-4a59-4e3c-b3d9-2c165744793f, 5.572706151674774, 5.54581460272596
# c3302808-38fa-4f49-a4e0-b6b6bb2a9ea8, 6.071424329058926, 6.196201007330149
# c673ca6d-116c-41e0-b87b-0b6be5edb373, 4.302835776073075, 4.279778164562111
# c774e933-8fd9-48d2-ab6b-fdf939760e98, 6.935945181690574, 7.186323639344505
# cc25aa67-67bf-42d3-a332-6d9d5bd0f520, 5.7860250322202855, 5.941820152126656
# ccfb8830-08fb-4462-9e7a-a16034f65024, 4.526769628107594, 4.290159568791632
# d34c301f-2abc-4277-a1ef-ef38935f68b2, 5.129529303748468, 5.089361130777558
# d491e62d-beab-4b98-9967-57db5d64ad1b, 6.596852624969255, 6.706793090615139
# d4bb8c6c-18e6-46a7-9ee9-bc8c50119e55, 5.721418700782013, 5.985442100143589
# d875c370-f30b-473b-9638-e3af466866c4, 5.49975625926455, 5.510318987133067
# d9151f3b-1e2a-4885-b9ea-9d5cf2b745da, 6.190414922231677, 6.133156540662104
# dc258a3e-b6c6-4be3-ab24-c37eb9242bcd, 5.476263865155637, 5.469603506821693
# dcbb9bcd-53a2-4c12-ab7e-7f6e6125da64, 6.904717134399686, 6.982573610969075
# dec8ca47-c9f9-4943-a477-b69d95a3a3f0, 6.981201422661388, 7.0193233269773225
# df1a5bdb-034c-414b-a469-46c8d85b4c24, 7.472627974732889, 7.714880452418921
# e57a46a3-8e45-4fa8-a5b6-30ddf0def6ac, 6.381615998370614, 6.53699669718753
# efbfa117-850d-4d95-b764-4fd553f3cdf2, 6.6232104038263335, 6.864262273760978
# f0dd6513-a5cd-432d-8792-eb32bb328d6d, 5.132825754390426, 5.360358381718338
# f10f5f3e-cc5f-4230-8395-13977fe4f173, 7.607811719679702, 7.920833571551963
# fb57064d-bc98-4221-b0fa-8fd036c9ba30, 5.553062473424148, 5.428264621573248

# %%
tempo = pd.read_csv("../Dataset 2.0/Decisions.csv")
tempo = tempo[tempo["Round"] == 5]
tempo = tempo[tempo["Session ID"] == "1997d08b-dc63-4ad1-9fb4-c8dc91c25a97"]
tempo = tempo.sort_values("Worker Agent ID")
tempo
# Out:
#             ID                            Session ID  Round  Worker Agent ID  \
# 278966  781319  1997d08b-dc63-4ad1-9fb4-c8dc91c25a97      5                2
# 278967  781321  1997d08b-dc63-4ad1-9fb4-c8dc91c25a97      5                3
# 278968  781323  1997d08b-dc63-4ad1-9fb4-c8dc91c25a97      5                4
# 278969  781325  1997d08b-dc63-4ad1-9fb4-c8dc91c25a97      5                5
# 278970  781327  1997d08b-dc63-4ad1-9fb4-c8dc91c25a97      5                6
# 278971  781329  1997d08b-dc63-4ad1-9fb4-c8dc91c25a97      5                7
# 278972  781331  1997d08b-dc63-4ad1-9fb4-c8dc91c25a97      5                8
# 278973  781333  1997d08b-dc63-4ad1-9fb4-c8dc91c25a97      5                9
# 278974  781335  1997d08b-dc63-4ad1-9fb4-c8dc91c25a97      5               10
#
#         Worker Agent Reputation
# 278966                 0.500000
# 278967                 0.500000
# 278968                 0.616089
# 278969                 0.532923
# 278970                 0.842789
# 278971                 0.433172
# 278972                 0.619297
# 278973                 0.740940
# 278974                 0.906759
