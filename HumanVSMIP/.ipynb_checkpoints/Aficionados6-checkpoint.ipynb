# %%
import pandas as pd
import numpy as np

#Importo il .csv contenente le varie sessioni di gioco
game_session = pd.read_csv("../Dataset 2.0/Game Sessions.csv")

#Estraggo da questo file 
uniquePlayers = np.unique(game_session["User ID"])

#Estraggo una lista di tutti i giocatori con un numero di partite giocate maggiroe di 30
users = []
for i in uniquePlayers:
    tmp = game_session[game_session["User ID"] == i]
    if len(tmp) > 30:
        users.append(i)
        
        
print(f"Sono presenti {len(users)} users con più di 30 game session giocate: {users}")
# Out:
# Sono presenti 34 users con più di 30 game session giocate: ['000a62d8-5e6d-4532-ad99-af8a92a7e7f3', '00212664-6c71-4e24-b61d-c7776f7a7d99', '12b5a3b6-ccd8-4259-9943-ea4d34a89a1a', '28c1a568-4a34-4c0a-90c9-da8150390e88', '2fe37a4e-2f03-4573-844f-ee523105dc00', '3452d36a-8ed4-4253-b9db-d8fbeb74638e', '453c69f9-3e08-46f4-9c34-b036575a342e', '46da2a87-6999-4690-a45f-89f69c9d9a15', '4a7b26aa-bed3-4660-8014-fa2d51e21030', '4a8258fd-a3fc-4816-afc7-9f62a17a0664', '574e89d2-8320-4f63-a8e4-4d25fb9b3e8d', '6afc891c-1442-4d1d-9660-00e28fa16489', '6e9c88f4-0b93-4c2f-a681-a72a30e41b64', '704e4795-fc54-4e87-a764-aa49ba52011d', '70506f5d-00ac-4ac5-9e9c-6fd6406016af', '74ddab53-3849-4848-a0df-efb50e0eba8f', '85c24634-825e-4f55-99e7-fe3c1c00ebbc', '863b4b11-6da2-44b9-8e21-4f5954ed5b04', '8db00f0c-87e8-4515-b73e-2e67244c7198', '92927f86-f921-4e6d-996e-9f337b6b2877', '9caf068d-5e86-4818-8d83-379ea55d4e6f', '9da6520c-97c9-4c23-9d6a-ea5a603b5163', 'adc3fcd1-e4bf-42a5-b9c6-5a9a0b307cef', 'bdf52837-f61c-402a-b1c5-5d5b943b51b1', 'c1f00487-661e-4dd1-9bdb-7f22e3fb0025', 'c5576f06-432f-4aaf-bc88-a18dfc2b213f', 'c785d937-d9a7-42a7-8596-4f41c550d747', 'cfab3001-b954-4a01-a1c6-b8173a2f0a36', 'e4a00228-4aad-4830-b9fb-6fc200792ec1', 'ea6e6aa6-c30a-4e8b-92ea-97fa67a27df2', 'f2dabbf8-5e14-4107-93b1-5384f1538a0d', 'f5901766-c557-4207-87cb-974e588b2351', 'f836c650-861b-4348-9c0a-554a13aaf310', 'f8692315-0df8-4d7c-b3f1-7b1970ab72b3']

# %%
#Estraggo ora solamente le sessioni di gioco riferite al livello 5
lista = []
for i in users:
    tmp = game_session[game_session["User ID"] == i]
    tmp = tmp[tmp["Game Level"] == 6]
    for i in range(len(tmp)):
        lista.append(tmp.iloc[i, 0])

#
lista = np.array(lista)
lista = np.unique(lista)


lista = np.delete(lista, 7)
lista = np.delete(lista, 9)
lista = np.delete(lista, 17)
lista = np.delete(lista, 18)
lista = np.delete(lista, 23)
lista = np.delete(lista, 23)
lista = np.delete(lista, 24)
lista = np.delete(lista, 26)
lista = np.delete(lista, 29)
lista = np.delete(lista, 34)
lista = np.delete(lista, 35)
lista = np.delete(lista, 35)
lista = np.delete(lista, 38)
lista = np.delete(lista, 52)
lista = np.delete(lista, 53)
lista = np.delete(lista, 54)
lista = np.delete(lista, 54)
lista = np.delete(lista, 54)
lista = np.delete(lista, 55)
lista = np.delete(lista, 62)
lista = np.delete(lista, 68)
lista = np.delete(lista, 68)
lista = np.delete(lista, 76)
lista = np.delete(lista, 77)
lista = np.delete(lista, 77)
lista = np.delete(lista, 77)
lista = np.delete(lista, 85)
lista = np.delete(lista, 85)
lista = np.delete(lista, 85)
lista = np.delete(lista, 85)
lista = np.delete(lista, 85)
lista = np.delete(lista, 91)
lista = np.delete(lista, 93)
lista = np.delete(lista, 104)
lista = np.delete(lista, 105)
lista = np.delete(lista, 118)
lista = np.delete(lista, 127)
lista = np.delete(lista, 127)
lista = np.delete(lista, 132)
lista = np.delete(lista, 134)
lista = np.delete(lista, 135)
lista = np.delete(lista, 137)
lista = np.delete(lista, 147)
lista = np.delete(lista, 108)
lista = np.delete(lista, 117)
lista = np.delete(lista, 35)
lista = np.delete(lista, 6)
lista = np.delete(lista, 70)
lista = np.delete(lista, 67)

for i in range(len(lista)):
    if lista[i] == "683a881d-6c5b-4140-8c17-d31e084ffe5f":
        print(i)
        
lista
# Out:
# array(['0011664d-942a-4bf2-8ca0-1d3764432038',
#        '01a79c6c-c29e-4445-a2cc-1c8360333238',
#        '0299d363-efe8-4d0e-86a2-062ffa282088',
#        '033c71e4-8c6a-49f1-91f3-353754656c40',
#        '038d5903-b03b-45c1-852b-a9543b2f66c6',
#        '0555fd69-bac6-4599-a9f3-a73cb7aa2506',
#        '0785f678-56e8-4071-af9b-6b82fa8cb874',
#        '0840e846-4ef7-4245-958c-53f2103499f6',
#        '0e96c9aa-7686-4dba-bf63-f6b81a8ed46c',
#        '104aa07c-5bd1-455d-8d41-d2622d3d79ba',
#        '11bf44c9-774d-4bb8-b44d-1f0beb08fa14',
#        '129bfde4-8f70-4e75-9d9b-f30a924e8cc3',
#        '145ba662-9e6b-43c9-aaa8-ce586a31f1ff',
#        '15478b21-1a45-4d0e-ac95-7f9116a5a48a',
#        '1588aa4c-d5d8-43dc-9bbf-37025f80087c',
#        '1de81312-f6c8-40c0-affd-655e7cffad32',
#        '205c611e-ac68-47f1-bb4a-b2c7bbb9de1c',
#        '225d40f3-b7f8-4e8b-a5ee-bb161128d059',
#        '2435aa0f-3502-46f4-820f-ff48bd1a8759',
#        '25616609-cac7-49a2-ab8c-b9deb4889c48',
#        '258204df-e475-4f7f-90cc-2aa8db8c08f2',
#        '289c4cac-fef4-40a0-9f45-12fa316cdca0',
#        '2934af74-f4ed-42ce-9630-361c462183d6',
#        '2b24c945-bdc5-43f4-ae8a-43ca32509320',
#        '2da9c8ff-e264-493d-a7e0-b3120d4721ba',
#        '2f77c029-b0ae-4eee-bd4f-24a0ec1723f8',
#        'cdb3562c-dfc7-482a-b217-74f30778ad1a',
#        'cef0d374-8db6-4de7-8583-aabe3647b55f',
#        'cf4d5b94-1165-4003-ad03-a6ec61f0e29e',
#        'd767d599-2faa-4347-9b4c-64222a01f48f',
#        'd97c11ba-3513-4722-a925-508da8136afa',
#        'dc6cf48e-3431-4948-b707-c17d4f18b3e0',
#        'de87cca6-b421-451d-8534-d4ec5a739ce9',
#        'dea03740-8f3c-4156-9080-7491c3645699',
#        'e13e4539-8585-44cb-b046-36824fd4c820',
#        'e5ef6f51-0c82-4b3b-987d-93ac28a56c55',
#        'e96d8be7-c3c0-454d-a386-cfc0b1a4a45b',
#        'f680b11e-568d-4d72-be69-282b40a6becf',
#        'f6fe4346-14fc-44c9-b919-02e5dd0b7d05',
#        'f723835a-3fb8-46ea-9764-b84f0de94cd8',
#        'f7fce8da-6764-448c-b3e6-10ff1cb48cdd',
#        'f91cc7de-bbf1-449c-b1c3-f78febbe1fab',
#        'f9efb8f8-7038-460f-a081-2be393524fbc',
#        'fad98895-a696-4a4e-8cee-08ed1e8dc854',
#        'fee84bba-2a0e-4867-a240-15a0a5ed0aa8',
#        'fef32509-f760-47ba-8061-d2ad1d5d7527',
#        'ffb8a004-1533-437a-a432-9691129076a5'], dtype='<U36')

# %%
#Importo le informazioni riguardanti le qualità delle tasks
tasks = pd.read_csv("../Dataset 2.0/Tasks.csv")
tasks = tasks.drop(0, axis = 0)
tasks = tasks.drop("Deadline", axis = 1)


#Importo i coefficienti di regressione di ogni agente
coeffs = pd.read_csv("../Coefficienti di Regressione/coeffs.csv")

#Estraggo solamente i risultati del round desiderato
decisions = pd.read_csv("../Dataset 2.0/Decisions.csv")
decisions = decisions[decisions["Round"] == 9]
decisions
# Out:
#              ID                            Session ID  Round  Worker Agent ID  \
# 630        1521  cd6b97eb-16f5-486e-a29b-c3baf4c2baec      9               11
# 631        1523  cd6b97eb-16f5-486e-a29b-c3baf4c2baec      9               16
# 632        1525  cd6b97eb-16f5-486e-a29b-c3baf4c2baec      9               20
# 633        1527  cd6b97eb-16f5-486e-a29b-c3baf4c2baec      9               13
# 634        1529  cd6b97eb-16f5-486e-a29b-c3baf4c2baec      9               14
# ...         ...                                   ...    ...              ...
# 495388  1290646  b206c2c6-de43-414a-abbf-af57e750f906      9               16
# 495389  1290648  b206c2c6-de43-414a-abbf-af57e750f906      9               17
# 495390  1290650  b206c2c6-de43-414a-abbf-af57e750f906      9               18
# 495391  1290652  b206c2c6-de43-414a-abbf-af57e750f906      9               19
# 495392  1290654  b206c2c6-de43-414a-abbf-af57e750f906      9               20
#
#         Worker Agent Reputation
# 630                    0.093912
# 631                    0.307397
# 632                    0.319685
# 633                    0.160180
# 634                    0.313495
# ...                         ...
# 495388                 0.548162
# 495389                 0.690501
# 495390                 0.577292
# 495391                 0.774562
# 495392                 0.633201
#
# [18277 rows x 5 columns]

# %%
from mip import *


for i in lista:
    stringa = ""
    stringa = stringa + i + ", "
    #Selezionare il Session ID ed il Round voluti
    #Assicurarsi di selezionare lo stesso round in "RegressionModel.py" e in "OptimizationModel.py"
    decisions1 = decisions[decisions["Session ID"] == i]
    decisions1 = decisions1.sort_values("Worker Agent ID")
    m = Model()
    m.verbose = 0

    #DATI


    #Identifier del Worker Agent
    WAID = list(decisions1["Worker Agent ID"])

    #Peso dell'Identifier del WA
    wWAID = coeffs.iloc[91].values.tolist()

    if (WAID[9] == 10):
        wWAID = wWAID[0:10]

    else:
        wWAID = wWAID[10:20]

    #Identifier del Round
    dID = list(decisions["ID"])


    #Peso dell'Identifier del round
    wdID = coeffs.iloc[0].values.tolist()

    if (WAID[9] == 10):
        wdID = wdID[0:10]

    else:
        wdID = wdID[10:20]


    #Value di ogni task
    Value = []
    for h in tasks["Value"]:
        Value.append(int(h))


    #Peso del Value (coeffs 1, 4, 7, ..., 88)
    wValue = []

    j = 1
    for k in range(30):
        wValue.append(coeffs.iloc[j].values.tolist())
        j = j + 3

    if (WAID[9] == 10):
        for h in range(30):
            wValue[h] = wValue[h][0:10]

    else:
        for h in range(30):
            wValue[h] = wValue[h][10:20]


    #Complessità di ogni task
    Difficulty = []
    for h in tasks["Difficulty"]:
        Difficulty.append(float(h))


    #Peso della Complessità (coeffs 2, 5, 8, ..., 89)
    wDifficulty = []

    j = 2
    for k in range(30):
        wDifficulty.append(coeffs.iloc[j].values.tolist())
        j = j + 3

    if (WAID[9] == 10):
        for h in range(30):
            wDifficulty[h] = wDifficulty[h][0:10]

    else:
        for h in range(30):
            wDifficulty[h] = wDifficulty[h][10:20]


    #Stamina consumata da ogni task
    Effort = []
    for h in tasks["Effort Required"]:
        Effort.append(int(h))


    #Peso della Stamina consumata (coeffs 3, 6, 9, ..., 90)
    wEffort = []

    j = 3
    for k in range(30):
        wEffort.append(coeffs.iloc[j].values.tolist())
        j = j + 3

    if (WAID[9] == 10):
        for h in range(30):
            wEffort[h] = wEffort[h][0:10]

    else:
        for h in range(30):
            wEffort[h] = wEffort[h][10:20]

    #Reputazione del WA prima del round
    Rep = list(decisions1["Worker Agent Reputation"])


    #Peso della reputation
    wRep = coeffs.iloc[92].values.tolist()

    if (WAID[9] == 10):
        wRep = wRep[0:10]

    else:
        wRep = wRep[10:20]

    #creo i range utili per la creazione di variabili
    (A, T) = (range(len(WAID)), range(len(Value)))

    #VARIABILI

    #x[a, t] vale 1 se la task t è assegnata al WA a, 0 altrimenti
    x = [[m.add_var(var_type=BINARY) for t in T] for a in A]

    #y(a) contiene la reputation del WA a fine round
    y = [m.add_var(var_type=CONTINUOUS) for a in A]


    #VINCOLI

    #Vincolo che impone che ogni task venga assegnata ad uno ed un solo WA
    for t in T:
        m += xsum(x[a][t] for a in A) == 1


    #OBIETTIVO
    #Massimizzare la sommatoria delle reputation dei worker agent
    m.objective = maximize(xsum(dID[a]*wdID[a] for a in A) + xsum(wValue[t][a]*Value[t]*x[a][t] + wDifficulty[t][a]*Difficulty[t]*x[a][t] + wEffort[t][a]*Effort[t]*x[a][t] for t in T for a in A) + xsum(wRep[a]*Rep[a] + wWAID[a]*WAID[a] for a in A))

    m.write("model.lp")
    m.optimize()

    stringa = stringa +str(m.objective_value) + ", "



    decisions2 = pd.read_csv("../Dataset 2.0/Decisions.csv")

    #Da "Decisions.csv" seleziono solo le tuple riguardanti il round successivo
    decisions2 = decisions2[decisions2["Round"] == 10]

    #Estraggo "Session ID", "Worker Agent ID" e "Worker Agent Reputation"
    decisions2 = decisions2.iloc[:, [1, 3, 4]]
    decisions2 = decisions2[decisions2["Session ID"] == i]
    tmp1 = pd.merge(decisions1, decisions2, left_on = "Worker Agent ID", right_on = "Worker Agent ID")

    tmp1 = tmp1.iloc[:, [0, 1, 2, 3, 4, 6]]

    #calcolo lo score corrispondente ottenuto dal player umano
    totale = 0
    for k in range(len(tmp1)):
        totale += tmp1.iloc[k, 5]
    stringa = stringa + str(totale)
    print(stringa)
# Out:
# 0011664d-942a-4bf2-8ca0-1d3764432038, 4.897047923265226, 5.084480081552947
# 01a79c6c-c29e-4445-a2cc-1c8360333238, 4.484232513266643, 4.6474967354033145
# 0299d363-efe8-4d0e-86a2-062ffa282088, 5.037023858785871, 5.391867266402411
# 033c71e4-8c6a-49f1-91f3-353754656c40, 5.087715338058016, 5.086808032543009
# 038d5903-b03b-45c1-852b-a9543b2f66c6, 4.6529015945729, 5.101771747662123
# 0555fd69-bac6-4599-a9f3-a73cb7aa2506, 5.237534884080814, 5.612541382696829
# 0785f678-56e8-4071-af9b-6b82fa8cb874, 5.1028739226314155, 5.4579119057659025
# 0840e846-4ef7-4245-958c-53f2103499f6, 4.919055603541219, 5.357136578112631
# 0e96c9aa-7686-4dba-bf63-f6b81a8ed46c, 5.234455111835843, 5.762730490926306
# 104aa07c-5bd1-455d-8d41-d2622d3d79ba, 5.1705575816997085, 5.181538897930528
# 11bf44c9-774d-4bb8-b44d-1f0beb08fa14, 5.456242419805573, 5.901203088784684
# 129bfde4-8f70-4e75-9d9b-f30a924e8cc3, 4.889132544000541, 5.221344352804975
# 145ba662-9e6b-43c9-aaa8-ce586a31f1ff, 4.555840630198119, 4.586534955230427
# 15478b21-1a45-4d0e-ac95-7f9116a5a48a, 4.013557619858577, 4.422601150045613
# 1588aa4c-d5d8-43dc-9bbf-37025f80087c, 5.168234716895065, 5.440124605253631
# 1de81312-f6c8-40c0-affd-655e7cffad32, 6.377603314951842, 6.770813478834105
# 205c611e-ac68-47f1-bb4a-b2c7bbb9de1c, 5.133883035898058, 5.4595766825452525
# 225d40f3-b7f8-4e8b-a5ee-bb161128d059, 4.710184543922064, 4.8694116169643635
# 2435aa0f-3502-46f4-820f-ff48bd1a8759, 5.531061512661853, 5.754881565047903
# 25616609-cac7-49a2-ab8c-b9deb4889c48, 4.243180145497239, 4.4347326645295295
# 258204df-e475-4f7f-90cc-2aa8db8c08f2, 5.425653869555881, 5.437612485443913
# 289c4cac-fef4-40a0-9f45-12fa316cdca0, 5.684735818475255, 5.985910333202556
# 2934af74-f4ed-42ce-9630-361c462183d6, 5.0407309484805936, 5.142277765053563
# 2b24c945-bdc5-43f4-ae8a-43ca32509320, 5.6403504086504945, 5.952700951230571
# c4084598-686d-4a01-96f1-9e2adda636a8, 4.934242728216456, 4.844429374680334
# c66c2652-1949-4871-b4ae-00fa30710066, 5.334429618145612, 5.651474385199555
# c9c71bed-d7c0-4199-bce9-ce91211dbe05, 4.407545106544659, 4.523615785129005
# cdb3562c-dfc7-482a-b217-74f30778ad1a, 5.945571398198934, 6.278462813134257
# cef0d374-8db6-4de7-8583-aabe3647b55f, 4.187220440500003, 4.322354519659518
# cf4d5b94-1165-4003-ad03-a6ec61f0e29e, 6.1387390265008115, 6.39825465830323
# d767d599-2faa-4347-9b4c-64222a01f48f, 5.567711762531747, 5.957172958442298
# d97c11ba-3513-4722-a925-508da8136afa, 5.517810497469512, 5.985410323653063
# dc6cf48e-3431-4948-b707-c17d4f18b3e0, 5.971446139035938, 6.124628162210246
# de87cca6-b421-451d-8534-d4ec5a739ce9, 4.445000304736542, 4.622980874101167
# dea03740-8f3c-4156-9080-7491c3645699, 5.753867699222978, 5.854957148907
# e13e4539-8585-44cb-b046-36824fd4c820, 5.399963158937038, 5.753114544861342
# e5ef6f51-0c82-4b3b-987d-93ac28a56c55, 5.590133766621037, 5.866825909648176
# e96d8be7-c3c0-454d-a386-cfc0b1a4a45b, 4.540401872547692, 4.59007922744013
# f680b11e-568d-4d72-be69-282b40a6becf, 4.0331155279738296, 4.04133117427361
# f6fe4346-14fc-44c9-b919-02e5dd0b7d05, 5.393338753666037, 5.818866752528797
# f723835a-3fb8-46ea-9764-b84f0de94cd8, 5.914583162186785, 6.193271826423657
# f7fce8da-6764-448c-b3e6-10ff1cb48cdd, 6.288331006762862, 6.563625460606003
# f91cc7de-bbf1-449c-b1c3-f78febbe1fab, 4.462670123706084, 4.529730684350829
# f9efb8f8-7038-460f-a081-2be393524fbc, 5.7743863622375695, 6.118324159531466
# fad98895-a696-4a4e-8cee-08ed1e8dc854, 6.4974950699885, 6.799387086527327
# fee84bba-2a0e-4867-a240-15a0a5ed0aa8, 5.444624093806581, 5.636732177563112
# fef32509-f760-47ba-8061-d2ad1d5d7527, 5.2434834088387525, 5.249785890536431
# ffb8a004-1533-437a-a432-9691129076a5, 5.836647378738779, 6.3284660582070265

# %%
tempo = pd.read_csv("../Dataset 2.0/Decisions.csv")
tempo = tempo[tempo["Round"] == 9]
tempo = tempo[tempo["Session ID"] == "683a881d-6c5b-4140-8c17-d31e084ffe5f"]
tempo = tempo.sort_values("Worker Agent ID")
tempo
# Out:
#            ID                            Session ID  Round  Worker Agent ID  \
# 87149  278997  683a881d-6c5b-4140-8c17-d31e084ffe5f      9               11
# 87148  278995  683a881d-6c5b-4140-8c17-d31e084ffe5f      9               12
# 87147  278993  683a881d-6c5b-4140-8c17-d31e084ffe5f      9               14
# 87154  279007  683a881d-6c5b-4140-8c17-d31e084ffe5f      9               15
# 87155  279009  683a881d-6c5b-4140-8c17-d31e084ffe5f      9               16
# 87150  278999  683a881d-6c5b-4140-8c17-d31e084ffe5f      9               17
# 87152  279003  683a881d-6c5b-4140-8c17-d31e084ffe5f      9               18
# 87151  279001  683a881d-6c5b-4140-8c17-d31e084ffe5f      9               19
# 87153  279005  683a881d-6c5b-4140-8c17-d31e084ffe5f      9               20
#
#        Worker Agent Reputation
# 87149                 0.379535
# 87148                 0.418593
# 87147                 0.533856
# 87154                 0.467414
# 87155                 0.647087
# 87150                 0.582905
# 87152                 0.537795
# 87151                 0.669173
# 87153                 0.600905
